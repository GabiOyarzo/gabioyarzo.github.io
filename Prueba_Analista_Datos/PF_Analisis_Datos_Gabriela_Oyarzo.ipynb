# %% [markdown]
# # Prueba - Análisis de datos para optimización de ventas online
#
# *Gabriela Oyarzo*

# %% [markdown]
# 1. Limpieza y estandarización de datos (3 Puntos)
#
# En una hoja que nombrarás "Ventas_Limpias":
#
# - Importa los datos del archivo de apoyo (pestaña "Ventas_Raw").
# - Elimina los registros duplicados basándote en el ID de transacción.
# - Estandariza los nombres de las categorías para que todas comiencen con mayúscula y elimina espacios extra.
# - Corrige los valores en la columna "Canal" para que solo contengan "Web" o "App".
# - Reemplaza los valores faltantes en la columna "Región" con "No especifi cado".

# %% [markdown]
# Entrega resultados con nombre: QuickShop_Analisis_Gabriela_Oyarzo.xlsx
